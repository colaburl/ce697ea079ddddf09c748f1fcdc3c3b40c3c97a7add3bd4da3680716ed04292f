# %%
# !pip install -q git+https://github.com/naver/splade
# !pip install -q git+https://github.com/seanmacavaney/pyt_splade@misc

# %%
import pandas as pd
import pyterrier as pt ; pt.init()
import pyt_splade

# %%
factory = pyt_splade.SpladeFactory(agg='max')

# %%
query_pipeline = factory.query()

# %%
query_pipeline(pd.DataFrame([
  {'qid': '1112389', 'query': 'what is the county for grand rapids, mnasdfasdfasdf'},
]))
